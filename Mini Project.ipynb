# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime
import dateutil.parser

# %%
online_retail = pd.read_csv('Online_Retail.csv')
online_retail
# Out:
#        InvoiceNo InvoiceDate  InvoiceTime StockCode  \
# 0         536365  01-12-2010  08:26:00 AM    85123A
# 1         536365  01-12-2010  08:26:00 AM     71053
# 2         536365  01-12-2010  08:26:00 AM    84406B
# 3         536365  01-12-2010  08:26:00 AM    84029G
# 4         536365  01-12-2010  08:26:00 AM    84029E
# ...          ...         ...          ...       ...
# 541904    581587  09-12-2011  12:50:00 PM     22613
# 541905    581587  09-12-2011  12:50:00 PM     22899
# 541906    581587  09-12-2011  12:50:00 PM     23254
# 541907    581587  09-12-2011  12:50:00 PM     23255
# 541908    581587  09-12-2011  12:50:00 PM     22138
#
#                                 Description  Quantity  UnitPrice  Totalsale  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6       2.55      15.30
# 1                       WHITE METAL LANTERN         6       3.39      20.34
# 2            CREAM CUPID HEARTS COAT HANGER         8       2.75      22.00
# ...

# %%
online_retail.head()
# Out:
#   InvoiceNo InvoiceDate  InvoiceTime StockCode  \
# 0    536365  01-12-2010  08:26:00 AM    85123A
# 1    536365  01-12-2010  08:26:00 AM     71053
# 2    536365  01-12-2010  08:26:00 AM    84406B
# 3    536365  01-12-2010  08:26:00 AM    84029G
# 4    536365  01-12-2010  08:26:00 AM    84029E
#
#                            Description  Quantity  UnitPrice  Totalsale  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER         6       2.55      15.30
# 1                  WHITE METAL LANTERN         6       3.39      20.34
# 2       CREAM CUPID HEARTS COAT HANGER         8       2.75      22.00
# 3  KNITTED UNION FLAG HOT WATER BOTTLE         6       3.39      20.34
# 4       RED WOOLLY HOTTIE WHITE HEART.         6       3.39      20.34
#
#    CustomerID         Country
# 0     17850.0  United Kingdom
# 1     17850.0  United Kingdom
# 2     17850.0  United Kingdom
# 3     17850.0  United Kingdom
# 4     17850.0  United Kingdom

# %%
online_retail.tail()
# Out:
#        InvoiceNo InvoiceDate  InvoiceTime StockCode  \
# 541904    581587  09-12-2011  12:50:00 PM     22613
# 541905    581587  09-12-2011  12:50:00 PM     22899
# 541906    581587  09-12-2011  12:50:00 PM     23254
# 541907    581587  09-12-2011  12:50:00 PM     23255
# 541908    581587  09-12-2011  12:50:00 PM     22138
#
#                             Description  Quantity  UnitPrice  Totalsale  \
# 541904      PACK OF 20 SPACEBOY NAPKINS        12       0.85      10.20
# 541905     CHILDREN'S APRON DOLLY GIRL          6       2.10      12.60
# 541906    CHILDRENS CUTLERY DOLLY GIRL          4       4.15      16.60
# 541907  CHILDRENS CUTLERY CIRCUS PARADE         4       4.15      16.60
# 541908    BAKING SET 9 PIECE RETROSPOT          3       4.95      14.85
#
#         CustomerID Country
# 541904     12680.0  France
# 541905     12680.0  France
# 541906     12680.0  France
# 541907     12680.0  France
# 541908     12680.0  France

# %%
#this is used to check for sample, e.g you can check for 3 rows
online_retail.sample(n=3)
# Out:
#        InvoiceNo InvoiceDate  InvoiceTime StockCode  \
# 90703     544064  15-02-2011  01:50:00 PM     21272
# 465540    576245  14-11-2011  01:40:00 PM    85014B
# 9551      537207  05-12-2010  03:06:00 PM     22311
#
#                             Description  Quantity  UnitPrice  Totalsale  \
# 90703                SALLE DE BAIN HOOK         2       1.25       2.50
# 465540           RED RETROSPOT UMBRELLA         3       5.95      17.85
# 9551    OFFICE MUG WARMER BLACK+SILVER          1       2.95       2.95
#
#         CustomerID         Country
# 90703      17114.0  United Kingdom
# 465540     12553.0          France
# 9551       17402.0  United Kingdom

# %%
#see the lists of columns we have
online_retail.columns.to_list()
# Out:
# ['InvoiceNo',
#  'InvoiceDate',
#  'InvoiceTime',
#  'StockCode',
#  'Description',
#  'Quantity',
#  'UnitPrice',
#  'Totalsale',
#  'CustomerID',
#  'Country']

# %%
#can be used to check the data type
online_retail.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 10 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   InvoiceDate  541909 non-null  object
#  2   InvoiceTime  541909 non-null  object
#  3   StockCode    541909 non-null  object
#  4   Description  540455 non-null  object
#  5   Quantity     541909 non-null  int64
#  6   UnitPrice    541909 non-null  float64
#  7   Totalsale    541909 non-null  float64
#  8   CustomerID   406829 non-null  float64
#  9   Country      541909 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 41.3+ MB

# %%
#check for missing values
#Description has 1454 missing values
#Customer ID has 135080 missing values
online_retail.isna().sum()
# Out:
# InvoiceNo           0
# InvoiceDate         0
# InvoiceTime         0
# StockCode           0
# Description      1454
# Quantity            0
# UnitPrice           0
# Totalsale           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
#lets use a function
def missing_num(x):
    return sum(x.isnull())

print('Missing values per column')
#applying our function by column
#check sum of missing values by column, and get the columns where 
#the sum is not zero

print(online_retail.apply(missing_num, axis = 0))
# Out:
# Missing values per column
# InvoiceNo           0
# InvoiceDate         0
# InvoiceTime         0
# StockCode           0
# Description      1454
# Quantity            0
# UnitPrice           0
# Totalsale           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
#lamda arguments:expression
#it is used to print the missing values only. It doesnt print the column without a missing value
print('The missing value without having zero')
print(online_retail.apply(missing_num, axis = 0).where(lambda x: x!=0).dropna())
# Out:
# The missing value without having zero
# Description      1454.0
# CustomerID     135080.0
# dtype: float64

# %%
#To check for the specific values in countries
online_retail['Country'].unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
#We can check the key summaries of the dataset (numerical column)
#using the describe method

online_retail.describe()
# Out:
#             Quantity      UnitPrice      Totalsale     CustomerID
# count  541909.000000  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114      17.987795   15287.690570
# std       218.081158      96.759853     378.810824    1713.600303
# min    -80995.000000  -11062.060000 -168469.600000   12346.000000
# 25%         1.000000       1.250000       3.400000   13953.000000
# 50%         3.000000       2.080000       9.750000   15152.000000
# 75%        10.000000       4.130000      17.400000   16791.000000
# max     80995.000000   38970.000000  168469.600000   18287.000000

# %%
# Get the summary of the object data type
categorical = online_retail.dtypes[online_retail.dtypes == 'object']. index
online_retail[categorical].describe()
# Out:
#        InvoiceNo InvoiceDate  InvoiceTime StockCode  \
# count     541909      541909       541909    541909
# unique     25900         305          774      4070
# top       573585  05-12-2011  03:56:00 PM    85123A
# freq        1114        5331         2628      2313
#
#                                Description         Country
# count                               540455          541909
# unique                                4223              38
# top     WHITE HANGING HEART T-LIGHT HOLDER  United Kingdom
# freq                                  2369          495478

# %%
categorical
# Out:
# Index(['InvoiceNo', 'InvoiceDate', 'InvoiceTime', 'StockCode', 'Description',
#        'Country'],
#       dtype='object')

# %%
columns = ['InvoiceDate', 'Totalsale']
Sales_trend = online_retail[columns]
Sales_trend
# Out:
#        InvoiceDate  Totalsale
# 0       01-12-2010      15.30
# 1       01-12-2010      20.34
# 2       01-12-2010      22.00
# 3       01-12-2010      20.34
# 4       01-12-2010      20.34
# ...            ...        ...
# 541904  09-12-2011      10.20
# 541905  09-12-2011      12.60
# 541906  09-12-2011      16.60
# 541907  09-12-2011      16.60
# 541908  09-12-2011      14.85
#
# [541909 rows x 2 columns]

# %%
#To get total sales trend per month we need to:
#Convert the date column to date time object for it to work.
time_col = 'InvoiceDate'
online_retail[time_col] = pd.to_datetime(online_retail[time_col])
online_retail.InvoiceDate
# Out:
# 0        2010-01-12
# 1        2010-01-12
# 2        2010-01-12
# 3        2010-01-12
# 4        2010-01-12
#             ...
# 541904   2011-09-12
# 541905   2011-09-12
# 541906   2011-09-12
# 541907   2011-09-12
# 541908   2011-09-12
# Name: InvoiceDate, Length: 541909, dtype: datetime64[ns]

# %%
time_data = online_retail.resample ('M', on = time_col)['Totalsale'].sum().fillna(0)
time_data
fig, ax = plt.subplots(figsize = (16,6))
ax.plot(time_data)
plt.title('Total Sales Trend from 2010-2012 per month')
# Out:
# Text(0.5, 1.0, 'Total Sales Trend from 2010-2012 per month')

# %%
#dataset for only Netherlands
online_Nlsretail = online_retail[online_retail.Country == 'Netherlands']
online_Nlsretail
# Out:
#        InvoiceNo InvoiceDate  InvoiceTime StockCode  \
# 385       536403  2010-01-12  11:27:00 AM     22867
# 386       536403  2010-01-12  11:27:00 AM      POST
# 37952     539491  2010-12-20  10:09:00 AM     21981
# 37953     539491  2010-12-20  10:09:00 AM     21986
# 37954     539491  2010-12-20  10:09:00 AM     22720
# ...          ...         ...          ...       ...
# 534958    581176  2011-07-12  03:19:00 PM     22908
# 534959    581176  2011-07-12  03:19:00 PM     22907
# 534960    581176  2011-07-12  03:19:00 PM     22029
# 534961    581176  2011-07-12  03:19:00 PM     22712
# 537783    581338  2011-08-12  12:12:00 PM     23344
#
#                               Description  Quantity  UnitPrice  Totalsale  \
# 385               HAND WARMER BIRD DESIGN        96       1.85     177.60
# 386                               POSTAGE         1      15.00      15.00
# 37952        PACK OF 12 WOODLAND TISSUES         12       0.29       3.48
# ...

# %%
# Top 5 countries with highest sales are United Kingdom, Netherland, EIRE, Germany and France
# set width and height of the figure
plt.figure(figsize=(16,6))

#Add title
plt.title('Total Sales per country')

p = sns.barplot(x=online_retail.Country, y=online_retail.Totalsale, data = online_retail,
                estimator=np.sum)
#set the y axis label
plt.ylabel('Total Sale')
plt.xlabel('Country')
p.set_xticklabels (p.get_xticklabels(), rotation = -45);

# %%
time_data = online_Nlsretail.resample ('M', on = time_col)['Totalsale'].sum().fillna(0)
time_data
fig, ax = plt.subplots(figsize = (16,6))
ax.plot(time_data)
plt.title('Total Netherlands Sales Trend from 2010-2012 per week')
# Out:
# Text(0.5, 1.0, 'Total Netherlands Sales Trend from 2010-2012 per week')

# %%
#Sales trend in the UK                  
time_data = online_ukretail.resample ('M', on = time_col)['Totalsale'].sum().fillna(0)
time_data
fig, ax = plt.subplots(figsize = (16,6))
ax.plot(time_data)
plt.title('Total UK Sales Trend from 2010-2012 per month')
# Out:
# Text(0.5, 1.0, 'Total UK Sales Trend from 2010-2012 per month')

# %%
#Relationship between Quantity and Price of Online Goods.
#We can see that there is little or no correlation between Quantity and Unit Price.

ax = sns.regplot(x = 'Quantity', y = 'UnitPrice', data = online_retail)

# %%
online_ukretail = online_retail[online_retail.Country == 'United Kingdom']
online_ukretail
# Out:
#        InvoiceNo InvoiceDate  InvoiceTime StockCode  \
# 0         536365  2010-01-12  08:26:00 AM    85123A
# 1         536365  2010-01-12  08:26:00 AM     71053
# 2         536365  2010-01-12  08:26:00 AM    84406B
# 3         536365  2010-01-12  08:26:00 AM    84029G
# 4         536365  2010-01-12  08:26:00 AM    84029E
# ...          ...         ...          ...       ...
# 541889    581585  2011-09-12  12:31:00 PM     22466
# 541890    581586  2011-09-12  12:49:00 PM     22061
# 541891    581586  2011-09-12  12:49:00 PM     23275
# 541892    581586  2011-09-12  12:49:00 PM     21217
# 541893    581586  2011-09-12  12:49:00 PM     20685
#
#                                 Description  Quantity  UnitPrice  Totalsale  \
# 0        WHITE HANGING HEART T-LIGHT HOLDER         6       2.55      15.30
# 1                       WHITE METAL LANTERN         6       3.39      20.34
# 2            CREAM CUPID HEARTS COAT HANGER         8       2.75      22.00
# ...

# %%
# To check for the min, the first quartile, second quartile(median), third quartile and max value of 
#United Kingdom because it had the highest sales.

Country = 'United Kingdom'
online_ukretail = online_retail[online_retail.Country == Country]
p = sns.boxplot(x = 'Country', y = 'Totalsale', data =online_ukretail)

p.set(title =  f'Total Sales for {Country}')
p.set_xticklabels(p.get_xticklabels(), rotation = -45)
# Out:
# [Text(0, 0, 'United Kingdom')]

# %%
#Histogram
#lets look for total sales above 100,000
large_sales = online_retail[(online_retail['Totalsale']>2000)]
large_sales
# Out:
#        InvoiceNo InvoiceDate  InvoiceTime  StockCode  \
# 15017     537632  2010-07-12  03:08:00 PM  AMAZONFEE
# 16427     537657  2010-07-12  04:42:00 PM      22189
# 16428     537657  2010-07-12  04:42:00 PM      22188
# 16429     537657  2010-07-12  04:42:00 PM      21623
# 16435     537659  2010-07-12  04:43:00 PM      22189
# ...          ...         ...          ...        ...
# 533812    581115  2011-07-12  12:20:00 PM      22413
# 534952    581175  2011-07-12  03:16:00 PM      23084
# 537883    581375  2011-08-12  12:36:00 PM      21137
# 540061    581457  2011-08-12  06:43:00 PM      23543
# 540421    581483  2011-09-12  09:15:00 AM      23843
#
#                             Description  Quantity  UnitPrice  Totalsale  \
# 15017                        AMAZON FEE         1   13541.33   13541.33
# 16427           CREAM HEART CARD HOLDER       972       2.31    2245.32
# 16428           BLACK HEART CARD HOLDER       972       2.31    2245.32
# ...

# %%
#the seaborn displot would be used to check the univariate distribution of total sale
#against the large sales
sns.distplot(large_sales['Totalsale'])

# %%
# I encountered an error when working on the histogram
#is there a reason for this error?
sns.histplot(large_sales['Totalsale'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-984b1f153d18> in <module>
#       1 # I encountered an error when working on the histogram
#       2 #is there a reason for this error?
# ----> 3 sns.histplot(large_sales['Totalsale'])
#
# AttributeError: module 'seaborn' has no attribute 'histplot'
